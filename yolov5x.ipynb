# %%
print ("kernel")
# Out:
# kernel

# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# PyTorch version: 2.7.1+cu126
# CUDA available: True
# GPU Name: NVIDIA GeForce RTX 3050 Ti Laptop GPU

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5x')
# Out:
# Using cache found in C:\Users\madha/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2025-7-31 Python-3.11.0 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
#
# ...
# 100%|██████████| 166M/166M [03:36<00:00, 803kB/s]
#
# Fusing layers...
# YOLOv5x summary: 444 layers, 86705005 parameters, 0 gradients, 205.5 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 80, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(80, 160, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(160, 80, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(160, 80, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path="C:/tpddl/yolov5/runs/train/exp/weights/last.pt", force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\madha/.cache\torch\hub\master.zip
# C:\Users\madha/.cache\torch\hub\ultralytics_yolov5_master\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# YOLOv5  2025-8-2 Python-3.11.0 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7039792 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
import torch
torch.cuda.empty_cache()
print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |  65471 KiB |  70322 KiB | 192288 KiB | 126817 KiB |
# |       from large pool |  39808 KiB |  44548 KiB | 105364 KiB |  65556 KiB |
# |       from small pool |  25663 KiB |  26403 KiB |  86924 KiB |  61261 KiB |
# |---------------------------------------------------------------------------|
# | Active memory         |  65471 KiB |  70322 KiB | 192288 KiB | 126817 KiB |
# ...

# %%
# %cd yolov5/
num_epochs = 55
for epoch in range(num_epochs):
    print(f"Epoch [{epoch+1}/{num_epochs}]")
    # training code here...

# !python train.py --cos-lr --img 320 --batch-size -1 --epochs 1 --patience 50 --data "C:/tpddl/OCR_Meter_reading/OCR_Meter_reading/custom_data.yaml" --weights "C:/tpddl/yolov5x.pt" --cache  --workers 2 --device 0,1 --resume
# Out:
# [WinError 2] The system cannot find the file specified: 'yolov5/'
# c:\tpddl\yolov5
# Epoch [1/55]
# Epoch [2/55]
# Epoch [3/55]
# Epoch [4/55]
# Epoch [5/55]
# Epoch [6/55]
# Epoch [7/55]
# Epoch [8/55]
# Epoch [9/55]
# Epoch [10/55]
# Epoch [11/55]
# Epoch [12/55]
# Epoch [13/55]
# Epoch [14/55]
# Epoch [15/55]
# Epoch [16/55]
# Epoch [17/55]
# Epoch [18/55]
# Epoch [19/55]
# Epoch [20/55]
# Epoch [21/55]
# Epoch [22/55]
# Epoch [23/55]
# Epoch [24/55]
# Epoch [25/55]
# Epoch [26/55]
# Epoch [27/55]
# Epoch [28/55]
# Epoch [29/55]
# Epoch [30/55]
# Epoch [31/55]
# Epoch [32/55]
# Epoch [33/55]
# Epoch [34/55]
# Epoch [35/55]
# Epoch [36/55]
# Epoch [37/55]
# Epoch [38/55]
# Epoch [39/55]
# Epoch [40/55]
# Epoch [41/55]
# Epoch [42/55]
# Epoch [43/55]
# Epoch [44/55]
# Epoch [45/55]
# Epoch [46/55]
# Epoch [47/55]
# Epoch [48/55]
# Epoch [49/55]
# Epoch [50/55]
# Epoch [51/55]
# Epoch [52/55]
# Epoch [53/55]
# Epoch [54/55]
# Epoch [55/55]
# ...
