# %%
print ("kernel")
# Out:
# kernel

# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# PyTorch version: 2.7.1+cu126
# CUDA available: True
# GPU Name: NVIDIA GeForce RTX 3050 Ti Laptop GPU

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5x')
# Out:
# Using cache found in C:\Users\madha/.cache\torch\hub\ultralytics_yolov5_master
# C:\Users\madha/.cache\torch\hub\ultralytics_yolov5_master\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# YOLOv5  2025-8-8 Python-3.11.0 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
#
# Fusing layers...
# YOLOv5x summary: 444 layers, 86705005 parameters, 0 gradients, 205.5 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 80, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(80, 160, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(160, 80, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(160, 80, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Conv(
#           (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (4): C3(
#           (cv1): Conv(
#             (conv): Conv2d(320, 160, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(320, 160, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (4): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (5): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (6): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (7): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (5): Conv(
#           (conv): Conv2d(320, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (6): C3(
#           (cv1): Conv(
#             (conv): Conv2d(640, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(640, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (4): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (5): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (6): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (7): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (8): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (9): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (10): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (11): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (7): Conv(
#           (conv): Conv2d(640, 1280, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (8): C3(
#           (cv1): Conv(
#             (conv): Conv2d(1280, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1280, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (9): SPPF(
#           (cv1): Conv(
#             (conv): Conv2d(1280, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(2560, 1280, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         )
#         (10): Conv(
#           (conv): Conv2d(1280, 640, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (11): Upsample(scale_factor=2.0, mode='nearest')
#         (12): Concat()
#         (13): C3(
#           (cv1): Conv(
#             (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (14): Conv(
#           (conv): Conv2d(640, 320, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (15): Upsample(scale_factor=2.0, mode='nearest')
#         (16): Concat()
#         (17): C3(
#           (cv1): Conv(
#             (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (18): Conv(
#           (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (19): Concat()
#         (20): C3(
#           (cv1): Conv(
#             (conv): Conv2d(640, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(640, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (21): Conv(
#           (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (22): Concat()
#         (23): C3(
#           (cv1): Conv(
#             (conv): Conv2d(1280, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1280, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (24): Detect(
#           (m): ModuleList(
#             (0): Conv2d(320, 255, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(640, 255, kernel_size=(1, 1), stride=(1, 1))
#             (2): Conv2d(1280, 255, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path="C:/tpddl/yolov5/runs/train/exp/weights/last.pt", force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\madha/.cache\torch\hub\master.zip
# YOLOv5  2025-8-9 Python-3.11.0 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7039792 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
import torch
torch.cuda.empty_cache()
print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      | 755615 KiB | 760467 KiB |   2394 MiB |   1656 MiB |
# |       from large pool | 672976 KiB | 677716 KiB |   2102 MiB |   1445 MiB |
# |       from small pool |  82639 KiB |  83380 KiB |    291 MiB |    210 MiB |
# |---------------------------------------------------------------------------|
# | Active memory         | 755615 KiB | 760467 KiB |   2394 MiB |   1656 MiB |
# |       from large pool | 672976 KiB | 677716 KiB |   2102 MiB |   1445 MiB |
# |       from small pool |  82639 KiB |  83380 KiB |    291 MiB |    210 MiB |
# |---------------------------------------------------------------------------|
# | Requested memory      | 738802 KiB | 743654 KiB |   2347 MiB |   1625 MiB |
# |       from large pool | 656235 KiB | 660975 KiB |   2056 MiB |   1415 MiB |
# |       from small pool |  82567 KiB |  83308 KiB |    290 MiB |    209 MiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   | 778240 KiB | 778240 KiB | 778240 KiB |      0 B   |
# |       from large pool | 694272 KiB | 694272 KiB | 694272 KiB |      0 B   |
# |       from small pool |  83968 KiB |  83968 KiB |  83968 KiB |      0 B   |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  22624 KiB |  79886 KiB |   2046 MiB |   2024 MiB |
# |       from large pool |  21296 KiB |  76560 KiB |   1755 MiB |   1735 MiB |
# |       from small pool |   1328 KiB |   8601 KiB |    290 MiB |    288 MiB |
# |---------------------------------------------------------------------------|
# | Allocations           |     763    |     871    |    5772    |    5009    |
# |       from large pool |     124    |     125    |     422    |     298    |
# |       from small pool |     639    |     753    |    5350    |    4711    |
# |---------------------------------------------------------------------------|
# | Active allocs         |     763    |     871    |    5772    |    5009    |
# |       from large pool |     124    |     125    |     422    |     298    |
# |       from small pool |     639    |     753    |    5350    |    4711    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      75    |      75    |      75    |       0    |
# |       from large pool |      34    |      34    |      34    |       0    |
# |       from small pool |      41    |      41    |      41    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      34    |     102    |    2333    |    2299    |
# |       from large pool |       5    |      10    |     192    |     187    |
# |       from small pool |      29    |      97    |    2141    |    2112    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
# %cd yolov5/
# !python train.py --cos-lr --img 320 --batch-size -1 --epochs 100 --patience 0 --data "C:/tpddl/OCR_Meter_reading/OCR_Meter_reading/custom_data.yaml" --weights "C:/tpddl/yolov5x.pt" --cache  --workers 2 --device 0,1,-1 --resume
# Out:
# c:\tpddl\yolov5
# c:\tpddl\yolov5\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# WARNING:tensorflow:From c:\tpddl\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# train: weights=C:/tpddl/yolov5x.pt, cfg=, data=C:/tpddl/OCR_Meter_reading/OCR_Meter_reading/custom_data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=100, batch_size=-1, imgsz=320, rect=False, resume=True, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=0,1,-1, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=True, label_smoothing=0.0, patience=0, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github:  YOLOv5 is out of date by 1 commit. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5  v7.0-422-g2540fd4c Python-3.11.0 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5  runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      8800  models.common.Conv                      [3, 80, 6, 2, 2]
#   1                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   2                -1  4    309120  models.common.C3                        [160, 160, 4]
#   3                -1  1    461440  models.common.Conv                      [160, 320, 3, 2]
#   4                -1  8   2259200  models.common.C3                        [320, 320, 8]
#   5                -1  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#   6                -1 12  13125120  models.common.C3                        [640, 640, 12]
#   7                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 2]
#   8                -1  4  19676160  models.common.C3                        [1280, 1280, 4]
#   9                -1  1   4099840  models.common.SPPF                      [1280, 1280, 5]
#  10                -1  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  4   5332480  models.common.C3                        [1280, 640, 4, False]
#  14                -1  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  4   1335040  models.common.C3                        [640, 320, 4, False]
#  18                -1  1    922240  models.common.Conv                      [320, 320, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  4   4922880  models.common.C3                        [640, 640, 4, False]
#  21                -1  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  4  19676160  models.common.C3                        [1280, 1280, 4, False]
#  24      [17, 20, 23]  1    107664  models.yolo.Detect                      [11, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [320, 640, 1280]]
# Model summary: 445 layers, 86285104 parameters, 86285104 gradients, 204.8 GFLOPs
#
# Transferred 745/745 items from runs\train\exp5\weights\last.pt
# c:\tpddl\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# c:\tpddl\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed
# optimizer: SGD(lr=0.01) with parameter groups 123 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias
# Resuming training from runs\train\exp5\weights\last.pt from epoch 96 to 100 total epochs
#
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train...:   0%|          | 0/14859 [00:00<?, ?it/s]c:\tpddl\yolov5\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# c:\tpddl\yolov5\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# c:\tpddl\yolov5\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# c:\tpddl\yolov5\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# c:\tpddl\yolov5\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# c:\tpddl\yolov5\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# c:\tpddl\yolov5\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# c:\tpddl\yolov5\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# WARNING:tensorflow:From c:\tpddl\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\tpddl\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\tpddl\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\tpddl\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\tpddl\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\tpddl\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\tpddl\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\tpddl\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
#
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 1 images, 0 backgrounds, 0 corrupt:   0%|          | 1/14859 [00:23<98:42:45, 23.92s/it]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 49 images, 0 backgrounds, 0 corrupt:   0%|          | 49/14859 [00:24<1:25:25,  2.89it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 97 images, 0 backgrounds, 0 corrupt:   1%|          | 97/14859 [00:24<35:40,  6.90it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 145 images, 0 backgrounds, 0 corrupt:   1%|          | 145/14859 [00:24<19:37, 12.50it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 191 images, 0 backgrounds, 0 corrupt:   1%|▏         | 191/14859 [00:24<12:15, 19.95it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 237 images, 0 backgrounds, 0 corrupt:   2%|▏         | 237/14859 [00:24<08:05, 30.13it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 282 images, 0 backgrounds, 0 corrupt:   2%|▏         | 282/14859 [00:24<05:34, 43.52it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 330 images, 0 backgrounds, 0 corrupt:   2%|▏         | 330/14859 [00:24<03:52, 62.41it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 379 images, 0 backgrounds, 0 corrupt:   3%|▎         | 379/14859 [00:24<02:45, 87.31it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 427 images, 0 backgrounds, 0 corrupt:   3%|▎         | 427/14859 [00:24<02:03, 117.11it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 475 images, 0 backgrounds, 0 corrupt:   3%|▎         | 475/14859 [00:24<01:34, 151.95it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 522 images, 0 backgrounds, 0 corrupt:   4%|▎         | 522/14859 [00:25<01:15, 189.76it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 570 images, 0 backgrounds, 0 corrupt:   4%|▍         | 570/14859 [00:25<01:02, 229.71it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 617 images, 0 backgrounds, 0 corrupt:   4%|▍         | 617/14859 [00:25<00:52, 271.21it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 663 images, 0 backgrounds, 0 corrupt:   4%|▍         | 663/14859 [00:25<00:46, 307.87it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 709 images, 0 backgrounds, 0 corrupt:   5%|▍         | 709/14859 [00:25<00:42, 335.80it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 754 images, 0 backgrounds, 0 corrupt:   5%|▌         | 754/14859 [00:25<00:40, 352.51it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 802 images, 0 backgrounds, 0 corrupt:   5%|▌         | 802/14859 [00:25<00:37, 377.67it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 849 images, 0 backgrounds, 0 corrupt:   6%|▌         | 849/14859 [00:25<00:35, 399.47it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 894 images, 0 backgrounds, 0 corrupt:   6%|▌         | 894/14859 [00:25<00:33, 412.62it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 939 images, 0 backgrounds, 0 corrupt:   6%|▋         | 939/14859 [00:26<00:33, 415.52it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 985 images, 0 backgrounds, 0 corrupt:   7%|▋         | 985/14859 [00:26<00:32, 425.93it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 1030 images, 0 backgrounds, 0 corrupt:   7%|▋         | 1030/14859 [00:26<00:32, 430.98it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 1075 images, 0 backgrounds, 0 corrupt:   7%|▋         | 1075/14859 [00:26<00:32, 425.23it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 1122 images, 0 backgrounds, 0 corrupt:   8%|▊         | 1122/14859 [00:26<00:32, 426.71it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 1170 images, 0 backgrounds, 0 corrupt:   8%|▊         | 1170/14859 [00:26<00:31, 430.40it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 1219 images, 0 backgrounds, 0 corrupt:   8%|▊         | 1219/14859 [00:26<00:31, 436.10it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 1263 images, 0 backgrounds, 0 corrupt:   8%|▊         | 1263/14859 [00:26<00:31, 433.19it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 
/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 4514 images, 0 backgrounds, 0 corrupt:  30%|███       | 4514/14859 [00:33<00:23, 443.87it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 4562 images, 0 backgrounds, 0 corrupt:  31%|███       | 4562/14859 [00:34<00:23, 442.43it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 4610 images, 0 backgrounds, 0 corrupt:  31%|███       | 4610/14859 [00:34<00:23, 438.67it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 4658 images, 0 backgrounds, 0 corrupt:  31%|███▏      | 4658/14859 [00:34<00:23, 439.41it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 4706 images, 0 backgrounds, 0 corrupt:  32%|███▏      | 4706/14859 [00:34<00:23, 434.98it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 4754 images, 0 backgrounds, 0 corrupt:  32%|███▏      | 4754/14859 [00:34<00:23, 437.60it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 4802 images, 0 backgrounds, 0 corrupt:  32%|███▏      | 4802/14859 [00:34<00:22, 447.47it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 4850 images, 0 backgrounds, 0 corrupt:  33%|███▎      | 4850/14859 [00:34<00:22, 452.65it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 4896 images, 0 backgrounds, 0 corrupt:  33%|███▎      | 4896/14859 [00:34<00:21, 453.03it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 4942 images, 0 backgrounds, 0 corrupt:  33%|███▎      | 4942/14859 [00:34<00:22, 437.42it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 4986 images, 0 backgrounds, 0 corrupt:  34%|███▎      | 4986/14859 [00:35<00:22, 432.44it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5030 images, 0 backgrounds, 0 corrupt:  34%|███▍      | 5030/14859 [00:35<00:23, 425.19it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5075 images, 0 backgrounds, 0 corrupt:  34%|███▍      | 5075/14859 [00:35<00:23, 422.41it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5122 images, 0 backgrounds, 0 corrupt:  34%|███▍      | 5122/14859 [00:35<00:22, 434.71it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5170 images, 0 backgrounds, 0 corrupt:  35%|███▍      | 5170/14859 [00:35<00:22, 438.63it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5214 images, 0 backgrounds, 0 corrupt:  35%|███▌      | 5214/14859 [00:35<00:22, 436.28it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5259 images, 0 backgrounds, 0 corrupt:  35%|███▌      | 5259/14859 [00:35<00:22, 431.00it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5307 images, 0 backgrounds, 0 corrupt:  36%|███▌      | 5307/14859 [00:35<00:21, 436.65it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5355 images, 0 backgrounds, 0 corrupt:  36%|███▌      | 5355/14859 [00:35<00:21, 441.59it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5404 images, 0 backgrounds, 0 corrupt:  36%|███▋      | 5404/14859 [00:35<00:20, 454.92it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5452 images, 0 backgrounds, 0 corrupt:  37%|███▋      | 5452/14859 [00:36<00:20, 453.47it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5500 images, 0 backgrounds, 0 corrupt:  37%|███▋      | 5500/14859 [00:36<00:20, 458.16it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5548 images, 0 backgrounds, 0 corrupt:  37%|███▋      | 5548/14859 [00:36<00:20, 458.15it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5596 images, 0 backgrounds, 0 corrupt:  38%|███▊      | 5596/14859 [00:36<00:20, 458.95it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5642 images, 0 backgrounds, 0 corrupt:  38%|███▊      | 5642/14859 [00:36<00:20, 455.69it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5692 images, 0 backgrounds, 0 corrupt:  38%|███▊      | 5692/14859 [00:36<00:20, 458.08it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5740 images, 0 backgrounds, 0 corrupt:  39%|███▊      | 5740/14859 [00:36<00:19, 456.99it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5788 images, 0 backgrounds, 0 corrupt:  39%|███▉      | 5788/14859 [00:36<00:19, 455.10it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5836 images, 0 backgrounds, 0 corrupt:  39%|███▉      | 5836/14859 [00:36<00:19, 457.41it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5885 images, 0 backgrounds, 0 corrupt:  40%|███▉      | 5885/14859 [00:37<00:19, 462.09it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5933 images, 0 backgrounds, 0 corrupt:  40%|███▉      | 5933/14859 [00:37<00:19, 460.90it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 5981 images, 0 backgrounds, 0 corrupt:  40%|████      | 5981/14859 [00:37<00:19, 460.53it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 
/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 7631 images, 0 backgrounds, 0 corrupt:  51%|█████▏    | 7631/14859 [00:40<00:16, 429.36it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 7680 images, 0 backgrounds, 0 corrupt:  52%|█████▏    | 7680/14859 [00:41<00:16, 439.88it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 7728 images, 0 backgrounds, 0 corrupt:  52%|█████▏    | 7728/14859 [00:41<00:15, 450.64it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 7777 images, 0 backgrounds, 0 corrupt:  52%|█████▏    | 7777/14859 [00:41<00:15, 447.22it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 7825 images, 0 backgrounds, 0 corrupt:  53%|█████▎    | 7825/14859 [00:41<00:16, 435.99it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 7873 images, 0 backgrounds, 0 corrupt:  53%|█████▎    | 7873/14859 [00:41<00:15, 437.08it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 7921 images, 0 backgrounds, 0 corrupt:  53%|█████▎    | 7921/14859 [00:41<00:16, 431.57it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 7969 images, 0 backgrounds, 0 corrupt:  54%|█████▎    | 7969/14859 [00:41<00:15, 440.79it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8017 images, 0 backgrounds, 0 corrupt:  54%|█████▍    | 8017/14859 [00:41<00:15, 444.24it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8062 images, 0 backgrounds, 0 corrupt:  54%|█████▍    | 8062/14859 [00:41<00:15, 445.17it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8108 images, 0 backgrounds, 0 corrupt:  55%|█████▍    | 8108/14859 [00:42<00:15, 444.25it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8156 images, 0 backgrounds, 0 corrupt:  55%|█████▍    | 8156/14859 [00:42<00:14, 448.12it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8203 images, 0 backgrounds, 0 corrupt:  55%|█████▌    | 8203/14859 [00:42<00:14, 448.76it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8251 images, 0 backgrounds, 0 corrupt:  56%|█████▌    | 8251/14859 [00:42<00:14, 456.72it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8297 images, 0 backgrounds, 0 corrupt:  56%|█████▌    | 8297/14859 [00:42<00:14, 454.98it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8345 images, 0 backgrounds, 0 corrupt:  56%|█████▌    | 8345/14859 [00:42<00:14, 461.12it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8392 images, 0 backgrounds, 0 corrupt:  56%|█████▋    | 8392/14859 [00:42<00:14, 459.83it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8439 images, 0 backgrounds, 0 corrupt:  57%|█████▋    | 8439/14859 [00:42<00:13, 461.08it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8486 images, 0 backgrounds, 0 corrupt:  57%|█████▋    | 8486/14859 [00:42<00:14, 452.33it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8532 images, 0 backgrounds, 0 corrupt:  57%|█████▋    | 8532/14859 [00:42<00:14, 450.54it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8579 images, 0 backgrounds, 0 corrupt:  58%|█████▊    | 8579/14859 [00:43<00:14, 446.73it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8626 images, 0 backgrounds, 0 corrupt:  58%|█████▊    | 8626/14859 [00:43<00:13, 451.51it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8672 images, 0 backgrounds, 0 corrupt:  58%|█████▊    | 8672/14859 [00:43<00:13, 452.87it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8718 images, 0 backgrounds, 0 corrupt:  59%|█████▊    | 8718/14859 [00:43<00:13, 448.19it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8764 images, 0 backgrounds, 0 corrupt:  59%|█████▉    | 8764/14859 [00:43<00:13, 445.84it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8812 images, 0 backgrounds, 0 corrupt:  59%|█████▉    | 8812/14859 [00:43<00:13, 448.71it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8860 images, 0 backgrounds, 0 corrupt:  60%|█████▉    | 8860/14859 [00:43<00:13, 450.61it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8908 images, 0 backgrounds, 0 corrupt:  60%|█████▉    | 8908/14859 [00:43<00:13, 453.30it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 8956 images, 0 backgrounds, 0 corrupt:  60%|██████    | 8956/14859 [00:43<00:12, 456.45it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 9004 images, 0 backgrounds, 0 corrupt:  61%|██████    | 9004/14859 [00:44<00:12, 451.02it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 9052 images, 0 backgrounds, 0 corrupt:  61%|██████    | 9052/14859 [00:44<00:12, 455.08it/s]
# train: Scanning C:\Users\madha\Downloads\OCR_Meter_reading\OCR_Meter_reading\labels\train... 
/it]c:\tpddl\yolov5\train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#       99/99      5.28G    0.02184    0.02258   0.003009        214        320: 100%|█████████▉| 927/929 [2:07:04<00:13,  6.73s/it]
#       99/99      5.28G    0.02184    0.02258   0.003009        214        320: 100%|█████████▉| 928/929 [2:07:04<00:06,  6.77s/it]c:\tpddl\yolov5\train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#       99/99      5.28G    0.02184    0.02259   0.003009        133        320: 100%|█████████▉| 928/929 [2:07:08<00:06,  6.77s/it]
#       99/99      5.28G    0.02184    0.02259   0.003009        133        320: 100%|██████████| 929/929 [2:07:08<00:00,  6.10s/it]
#       99/99      5.28G    0.02184    0.02259   0.003009        133        320: 100%|██████████| 929/929 [2:07:08<00:00,  8.21s/it]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/5 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  20%|██        | 1/5 [00:01<00:06,  1.57s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  40%|████      | 2/5 [00:04<00:06,  2.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  60%|██████    | 3/5 [00:05<00:03,  1.89s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  80%|████████  | 4/5 [00:09<00:02,  2.60s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 5/5 [00:12<00:00,  2.70s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 5/5 [00:12<00:00,  2.45s/it]
#                    all        157        799      0.977      0.992      0.991      0.817
#
# 4 epochs completed in 13.142 hours.
# Optimizer stripped from runs\train\exp5\weights\last.pt, 173.1MB
# Optimizer stripped from runs\train\exp5\weights\best.pt, 173.1MB
#
# Validating runs\train\exp5\weights\best.pt...
# Fusing layers...
# Model summary: 322 layers, 86240704 parameters, 0 gradients, 204.0 GFLOPs
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/5 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  20%|██        | 1/5 [00:01<00:07,  1.92s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  40%|████      | 2/5 [00:05<00:08,  2.69s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  60%|██████    | 3/5 [00:08<00:05,  2.78s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  80%|████████  | 4/5 [00:11<00:02,  3.00s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 5/5 [00:14<00:00,  3.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|██████████| 5/5 [00:14<00:00,  2.95s/it]
#                    all        157        799      0.976      0.992      0.992      0.819
#                   zero        157        237      0.992      0.994      0.993      0.881
#                      1        157         53      0.978      0.981      0.981      0.693
#                      2        157         68      0.994          1      0.995       0.88
#                      3        157         55      0.993      0.982      0.993      0.857
#                      4        157         45      0.988          1      0.995      0.844
#                      5        157         48      0.989          1      0.995      0.888
#                      6        157         53      0.991          1      0.995      0.878
#                      7        157         34      0.987          1      0.995      0.851
#                      8        157         38      0.862          1      0.983      0.887
#                      9        157         24      0.983          1      0.995      0.893
#                    dot        157        144      0.979      0.959      0.989      0.453
# Results saved to runs\train\exp5

# %%
# !python export.py --weights "C:/tpddl/yolov5/runs/train/exp5/weights/best.pt" --include tflite --img 320
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(1, 320, 320, 3)]           0         []
#
#  tf_conv (TFConv)            (1, 160, 160, 80)            8720      ['input_1[0][0]']
#
#  tf_conv_1 (TFConv)          (1, 80, 80, 160)             115360    ['tf_conv[0][0]']
#
#  tfc3 (TFC3)                 (1, 80, 80, 160)             308160    ['tf_conv_1[0][0]']
#
#  tf_conv_13 (TFConv)         (1, 40, 40, 320)             461120    ['tfc3[0][0]']
#
#  tfc3_1 (TFC3)               (1, 40, 40, 320)             2256000   ['tf_conv_13[0][0]']
#
#  tf_conv_33 (TFConv)         (1, 20, 20, 640)             1843840   ['tfc3_1[0][0]']
#
#  tfc3_2 (TFC3)               (1, 20, 20, 640)             1311616   ['tf_conv_33[0][0]']
#                                                           0
#
#  tf_conv_61 (TFConv)         (1, 10, 10, 1280)            7374080   ['tfc3_2[0][0]']
#
#  tfc3_3 (TFC3)               (1, 10, 10, 1280)            1966848   ['tf_conv_61[0][0]']
#                                                           0
#
#  tfsppf (TFSPPF)             (1, 10, 10, 1280)            4097920   ['tfc3_3[0][0]']
#
#  tf_conv_75 (TFConv)         (1, 10, 10, 640)             819840    ['tfsppf[0][0]']
#
#  tf_upsample (TFUpsample)    (1, 20, 20, 640)             0         ['tf_conv_75[0][0]']
#
#  tf_concat (TFConcat)        (1, 20, 20, 1280)            0         ['tf_upsample[0][0]',
#                                                                      'tfc3_2[0][0]']
#
#  tfc3_4 (TFC3)               (1, 20, 20, 640)             5328640   ['tf_concat[0][0]']
#
#  tf_conv_87 (TFConv)         (1, 20, 20, 320)             205120    ['tfc3_4[0][0]']
#
#  tf_upsample_1 (TFUpsample)  (1, 40, 40, 320)             0         ['tf_conv_87[0][0]']
#
#  tf_concat_1 (TFConcat)      (1, 40, 40, 640)             0         ['tf_upsample_1[0][0]',
#                                                                      'tfc3_1[0][0]']
#
#  tfc3_5 (TFC3)               (1, 40, 40, 320)             1333120   ['tf_concat_1[0][0]']
#
#  tf_conv_99 (TFConv)         (1, 20, 20, 320)             921920    ['tfc3_5[0][0]']
#
#  tf_concat_2 (TFConcat)      (1, 20, 20, 640)             0         ['tf_conv_99[0][0]',
#                                                                      'tf_conv_87[0][0]']
#
#  tfc3_6 (TFC3)               (1, 20, 20, 640)             4919040   ['tf_concat_2[0][0]']
#
#  tf_conv_111 (TFConv)        (1, 10, 10, 640)             3687040   ['tfc3_6[0][0]']
#
#  tf_concat_3 (TFConcat)      (1, 10, 10, 1280)            0         ['tf_conv_111[0][0]',
#                                                                      'tf_conv_75[0][0]']
#
#  tfc3_7 (TFC3)               (1, 10, 10, 1280)            1966848   ['tf_concat_3[0][0]']
#                                                           0
#
#  tf_detect (TFDetect)        ((1, 6300, 16),              107664    ['tfc3_5[0][0]',
#                              )                                       'tfc3_6[0][0]',
#                                                                      'tfc3_7[0][0]']
#
# ==================================================================================================
# Total params: 86240704 (328.98 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 86240704 (328.98 MB)
# __________________________________________________________________________________________________
# c:\tpddl\yolov5\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# export: data=C:\tpddl\yolov5\data\coco128.yaml, weights=['C:/tpddl/yolov5/runs/train/exp5/weights/best.pt'], imgsz=[320], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5  v7.0-422-g2540fd4c Python-3.11.0 torch-2.7.1+cu126 CPU
#
# Fusing layers...
# Model summary: 322 layers, 86240704 parameters, 0 gradients, 204.0 GFLOPs
#
# PyTorch: starting from C:\tpddl\yolov5\runs\train\exp5\weights\best.pt with output shape (1, 6300, 16) (165.1 MB)
# WARNING:tensorflow:From c:\tpddl\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.15.1...
# WARNING  using Tensorflow 2.15.1 > 2.13.1 might cause issue when exporting the model to tflite https://github.com/ultralytics/yolov5/issues/12489
#
#                  from  n    params  module                                  arguments
# WARNING:tensorflow:From c:\tpddl\.venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
#   0                -1  1      8800  models.common.Conv                      [3, 80, 6, 2, 2]
#   1                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   2                -1  1    309120  models.common.C3                        [160, 160, 4]
#   3                -1  1    461440  models.common.Conv                      [160, 320, 3, 2]
#   4                -1  1   2259200  models.common.C3                        [320, 320, 8]
#   5                -1  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#   6                -1  1  13125120  models.common.C3                        [640, 640, 12]
#   7                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 2]
#   8                -1  1  19676160  models.common.C3                        [1280, 1280, 4]
# WARNING:tensorflow:From c:\tpddl\.venv\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
#   9                -1  1   4099840  models.common.SPPF                      [1280, 1280, 5]
#  10                -1  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1   5332480  models.common.C3                        [1280, 640, 4, False]
#  14                -1  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1   1335040  models.common.C3                        [640, 320, 4, False]
#  18                -1  1    922240  models.common.Conv                      [320, 320, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1   4922880  models.common.C3                        [640, 640, 4, False]
#  21                -1  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1  19676160  models.common.C3                        [1280, 1280, 4, False]
#  24      [17, 20, 23]  1    107664  models.yolo.Detect                      [11, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [320, 640, 1280], [320, 320]]
# TensorFlow SavedModel: export success  28.8s, saved as C:\tpddl\yolov5\runs\train\exp5\weights\best_saved_model (329.4 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.15.1...
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 278, Total Ops 1018, % non-converted = 27.31 %
#  * 278 ARITH ops
#
# - arith.constant:  278 occurrences  (f16: 263, i32: 15)
#
#
#
#   (f32: 31)
#   (f32: 17)
#   (f32: 126)
#   (f32: 263)
#   (f32: 132)
#   (f32: 3)
#   (f32: 141)
#   (f32: 7)
#   (f32: 6)
#   (f32: 2)
#   (f32: 9)
# TensorFlow Lite: export success  205.4s, saved as C:\tpddl\yolov5\runs\train\exp5\weights\best-fp16.tflite (164.7 MB)
#
# Export complete (236.0s)
# Results saved to C:\tpddl\yolov5\runs\train\exp5\weights
# Detect:          python detect.py --weights C:\tpddl\yolov5\runs\train\exp5\weights\best-fp16.tflite
# Validate:        python val.py --weights C:\tpddl\yolov5\runs\train\exp5\weights\best-fp16.tflite
# PyTorch Hub:     model = torch.hub.load('ultralytics/yolov5', 'custom', 'C:\tpddl\yolov5\runs\train\exp5\weights\best-fp16.tflite')
# Visualize:       https://netron.app

# %%
# %cd yolov5/
# !python detect.py --weights "C:/tpddl/yolov5/runs/train/exp5/weights/best-fp16.tflite" --img 320 --conf 0.25 --source "C:/tpddl/yolov5/runs/train/exp5"/
# Out:
# [WinError 2] The system cannot find the file specified: 'yolov5/'
# c:\tpddl\yolov5
# c:\tpddl\yolov5\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# detect: weights=['C:/tpddl/yolov5/runs/train/exp5/weights/best-fp16.tflite'], source=C:/tpddl/yolov5/runs/train/exp5/, data=data\coco128.yaml, imgsz=[320, 320], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-422-g2540fd4c Python-3.11.0 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
#
# WARNING:tensorflow:From c:\tpddl\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Loading C:\tpddl\yolov5\runs\train\exp5\weights\best-fp16.tflite for TensorFlow Lite inference...
# Traceback (most recent call last):
#   File "c:\tpddl\yolov5\detect.py", line 438, in <module>
#     main(opt)
#   File "c:\tpddl\yolov5\detect.py", line 433, in main
#     run(**vars(opt))
#   File "c:\tpddl\.venv\Lib\site-packages\torch\utils\_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\tpddl\yolov5\detect.py", line 166, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\tpddl\yolov5\models\common.py", line 635, in __init__
#     interpreter = Interpreter(model_path=w)  # load TFLite model
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\tpddl\.venv\Lib\site-packages\tensorflow\lite\python\interpreter.py", line 464, in __init__
#     self._interpreter = _interpreter_wrapper.CreateWrapperFromFile(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: Could not open 'C:\tpddl\yolov5\runs\train\exp5\weights\best-fp16.tflite'.
